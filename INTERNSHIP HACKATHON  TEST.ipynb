# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\user\Downloads\movie_data\movies.csv")

# %%
data
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
# What is the shape of "movies.csv"?
data.shape
# Out:
# (9742, 3)

# %%
data1=pd.read_csv(r"C:\Users\user\Downloads\movie_data\ratings.csv")

# %%
data1
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
# What is the shape of "ratings.csv"
data1.shape
# Out:
# (100836, 4)

# %%
data2=pd.read_csv(r"C:\Users\user\Downloads\movie_data\links.csv")

# %%
data2
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9737   193581  5476944  432131.0
# 9738   193583  5914996  445030.0
# 9739   193585  6397426  479308.0
# 9740   193587  8391976  483455.0
# 9741   193609   101726   37891.0
#
# [9742 rows x 3 columns]

# %%
data3=pd.read_csv(r"C:\Users\user\Downloads\movie_data\tags.csv")

# %%
data3
# Out:
#       userId  movieId               tag   timestamp
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 3678     606     7382         for katie  1171234019
# 3679     606     7936           austere  1173392334
# 3680     610     3265            gun fu  1493843984
# 3681     610     3265  heroic bloodshed  1493843978
# 3682     610   168248  Heroic Bloodshed  1493844270
#
# [3683 rows x 4 columns]

# %%
# Which movie has recieved maximum number of user ratings?
unique_users_ids=data1["userId"].nunique()
print(unique_users_ids)
# Out:
# 610

# %%
# Select all the correct tags submitted by users to "Matrix, The (1999)" movie?
matrix_tags=data3[data3["movieId"]== 2571]["tag"]
print(matrix_tags)
# Out:
# 815           martial arts
# 816                 sci-fi
# 1646    alternate universe
# 2794            philosophy
# 2795      post apocalyptic
# Name: tag, dtype: object

# %%
mov_rat=pd.merge(data,data1,on="movieId",how="inner")

# %%
mov_rat
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100831   193581  Black Butler: Book of the Atlantic (2017)
# 100832   193583               No Game No Life: Zero (2017)
# 100833   193585                               Flint (2017)
# 100834   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# ...

# %%
mrt=pd.merge(mov_rat,data2,on="movieId",how="inner")

# %%
mrt
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100831   193581  Black Butler: Book of the Atlantic (2017)
# 100832   193583               No Game No Life: Zero (2017)
# 100833   193585                               Flint (2017)
# 100834   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# ...

# %%
# What is the average user rating for movie named "Terminator 2: Judgment Day (1991)"?

# %%
mov_rat
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100831   193581  Black Butler: Book of the Atlantic (2017)
# 100832   193583               No Game No Life: Zero (2017)
# 100833   193585                               Flint (2017)
# 100834   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# ...

# %%
mov_rat.loc[mov_rat["title"]== "Terminator 2: Judgment Day (1991)"]
# Out:
#        movieId                              title         genres  userId  \
# 15651      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi       5
# 15652      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi       6
# 15653      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi       7
# 15654      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi      11
# 15655      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi      15
# ...        ...                                ...            ...     ...
# 15870      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi     606
# 15871      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi     607
# 15872      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi     608
# 15873      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi     609
# 15874      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi     610
#
#        rating   timestamp
# 15651     3.0   847435258
# 15652     3.0   845553317
# ...

# %%
avg=mov_rat.loc[mov_rat["title"]== "Terminator 2: Judgment Day (1991)"]

# %%
avg["rating"].mean()
# Out:
# 3.970982142857143

# %%
# How does the data distribution of user ratings for "Fight Club (1999)" movie looks like?

# %%
mov_rat.loc[mov_rat["title"]=="Fight Club (1999)"]
# Out:
#        movieId              title                       genres  userId  \
# 49835     2959  Fight Club (1999)  Action|Crime|Drama|Thriller       1
# 49836     2959  Fight Club (1999)  Action|Crime|Drama|Thriller       4
# 49837     2959  Fight Club (1999)  Action|Crime|Drama|Thriller      10
# 49838     2959  Fight Club (1999)  Action|Crime|Drama|Thriller      15
# 49839     2959  Fight Club (1999)  Action|Crime|Drama|Thriller      16
# ...        ...                ...                          ...     ...
# 50048     2959  Fight Club (1999)  Action|Crime|Drama|Thriller     601
# 50049     2959  Fight Club (1999)  Action|Crime|Drama|Thriller     603
# 50050     2959  Fight Club (1999)  Action|Crime|Drama|Thriller     606
# 50051     2959  Fight Club (1999)  Action|Crime|Drama|Thriller     608
# 50052     2959  Fight Club (1999)  Action|Crime|Drama|Thriller     610
#
#        rating   timestamp
# 49835     5.0   964983282
# 49836     2.0   945078528
# 49837     0.5  1455356582
# ...

# %%
dist=mov_rat.loc[mov_rat["title"]=="Fight Club (1999)"]

# %%
sns.distplot(x=dist["rating"])
plt.axvline(dist["rating"],color="r",linestyle="--")
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12452\1585932923.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=dist["rating"])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 2
#       1 sns.distplot(x=dist["rating"])
# ----> 2 plt.axvline(dist["rating"],color="r",linestyle="--")
#       3 plt.show()
#
# File C:\DATA SCIENCE\Lib\site-packages\matplotlib\pyplot.py:2425, in axvline(x, ymin, ymax, **kwargs)
#    2423 @_copy_docstring_and_deprecators(Axes.axvline)
# ...

# %%
# Which movie is the most popular based on  average user ratings?
mov_rat.head(3)
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating   timestamp
# 0       1     4.0   964982703
# 1       5     4.0   847434962
# 2       7     4.5  1106635946

# %%
Godfather=mov_rat.loc[mov_rat["title"]=="Godfather, The (1972)"]

# %%
Godfather["rating"].mean()
# Out:
# 4.2890625

# %%
shaw=mov_rat.loc[mov_rat["title"]=="Shawshank Redemption, The (1994)"]

# %%
shaw["rating"].mean()
# Out:
# 4.429022082018927

# %%
jum=mov_rat.loc[mov_rat["title"]=="Jumanji (1995)"]

# %%
jum["rating"].mean()
# Out:
# 3.4318181818181817

# %%
Wolf=mov_rat.loc[mov_rat["title"]=="Wolf of Wall Street, The (2013)"]

# %%
Wolf["rating"].mean()
# Out:
# 3.9166666666666665

# %%
#Select all the correct options which comes under top 5 popular movies based on number of user ratings.
#Pulp Fiction (1994)      4.19e+
#Bad Boys (1995)          3.24e+
#Silence of the Lambs, The (1991)4.16e+
#Matrix, The (1999)        4.19e+

# %%
g=mov_rat.groupby("title")

# %%
g.ngroups
# Out:
# 9719

# %%
mov_rat.loc[mov_rat["rating"]==5.0]
# Out:
#         movieId                             title  \
# 9             1                  Toy Story (1995)
# 12            1                  Toy Story (1995)
# 13            1                  Toy Story (1995)
# 16            1                  Toy Story (1995)
# 19            1                  Toy Story (1995)
# ...         ...                               ...
# 100787   187593                 Deadpool 2 (2018)
# 100790   187593                 Deadpool 2 (2018)
# 100791   187593                 Deadpool 2 (2018)
# 100801   187595    Solo: A Star Wars Story (2018)
# 100802   187717  Won't You Be My Neighbor? (2018)
#
#                                              genres  userId  rating  \
# 9       Adventure|Animation|Children|Comedy|Fantasy      31     5.0
# 12      Adventure|Animation|Children|Comedy|Fantasy      40     5.0
# 13      Adventure|Animation|Children|Comedy|Fantasy      43     5.0
# 16      Adventure|Animation|Children|Comedy|Fantasy      46     5.0
# ...

# %%
p=mov_rat.loc[mov_rat["rating"]==5.0]

# %%
mov_rat.loc[mov_rat["title"]=="Pulp Fiction (1994)"].mean()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12452\526010556.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mov_rat.loc[mov_rat["title"]=="Pulp Fiction (1994)"].mean()
# movieId      2.960000e+02
# userId       2.951824e+02
# rating       4.197068e+00
# timestamp    1.137473e+09
# dtype: float64

# %%
mov_rat.loc[mov_rat["title"]=="Bad Boys (1995)"].mean()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12452\2343973510.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mov_rat.loc[mov_rat["title"]=="Bad Boys (1995)"].mean()
# movieId      1.450000e+02
# userId       3.447059e+02
# rating       3.245098e+00
# timestamp    1.089677e+09
# dtype: float64

# %%
mov_rat.loc[mov_rat["title"]=="Silence of the Lambs, The (1991)"].mean()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12452\3629222594.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mov_rat.loc[mov_rat["title"]=="Silence of the Lambs, The (1991)"].mean()
# movieId      5.930000e+02
# userId       3.065771e+02
# rating       4.161290e+00
# timestamp    1.147081e+09
# dtype: float64

# %%
mov_rat.loc[mov_rat["title"]=="Matrix, The (1999)",["rating"]].mean()
# Out:
# rating    4.192446
# dtype: float64

# %%
g.mean()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12452\2978112660.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.mean()
#                                             movieId      userId    rating  \
# title
# '71 (2014)                                 117867.0  610.000000  4.000000
# 'Hellboy': The Seeds of Creation (2004)     97757.0  332.000000  4.000000
# 'Round Midnight (1986)                      26564.0  354.500000  3.500000
# 'Salem's Lot (2004)                         27751.0  345.000000  5.000000
# 'Til There Was You (1997)                     779.0  229.000000  4.000000
# ...                                             ...         ...       ...
# eXistenZ (1999)                              2600.0  389.954545  3.863636
# ...

# %%
# Which Sci-Fi movie is "third most popular" based on the number of user ratings?
#Deadpool(2016)                       3.833
#Terminator 2: Judgement Day (1991)   3.97
#XMEN: The Last Stand (2006)          3.35
#Jurassic Park                        3.75

# %%
mov_rat
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100831   193581  Black Butler: Book of the Atlantic (2017)
# 100832   193583               No Game No Life: Zero (2017)
# 100833   193585                               Flint (2017)
# 100834   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# ...

# %%
mov_rat.loc[mov_rat["title"]=="Deadpool (2016)",["rating"]].mean()
# Out:
# rating    3.833333
# dtype: float64

# %%
mov_rat.loc[mov_rat["title"]=="Terminator 2: Judgment Day (1991)",["rating"]].mean()
# Out:
# rating    3.970982
# dtype: float64

# %%
mov_rat.loc[mov_rat["title"]=="X-Men: The Last Stand (2006)",["rating"]].mean()
# Out:
# rating    3.355769
# dtype: float64

# %%
mov_rat.loc[mov_rat["title"]=="Jurassic Park (1993)",["rating"]].mean()
# Out:
# rating    3.75
# dtype: float64

# %%
# Mention the movieId of the movie which has the highest IMDB rating.
max_imdb_movie_id = data2.loc[data2["imdbId"].idxmax(), "movieId"]
print(max_imdb_movie_id)
# Out:
# 193587

# %%
mov_rat=pd.merge(data,data1,on="movieId",how="inner")

# %%
mov_rat
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100831   193581  Black Butler: Book of the Atlantic (2017)
# 100832   193583               No Game No Life: Zero (2017)
# 100833   193585                               Flint (2017)
# 100834   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# ...

# %%
mrt=pd.merge(mov_rat,data2,on="movieId",how="inner")

# %%
mrt
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100831   193581  Black Butler: Book of the Atlantic (2017)
# 100832   193583               No Game No Life: Zero (2017)
# 100833   193585                               Flint (2017)
# 100834   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# ...

# %%
mrt.head(3)
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating   timestamp  imdbId  tmdbId
# 0       1     4.0   964982703  114709   862.0
# 1       5     4.0   847434962  114709   862.0
# 2       7     4.5  1106635946  114709   862.0

# %%
# Mention the movieId of the "Sci-Fi" movie which has the highest IMDB rating.
mrt.loc[mrt["genres"]=="Sci-Fi",["imdbId"]].max()
# Out:
# imdbId    2724064
# dtype: int64
